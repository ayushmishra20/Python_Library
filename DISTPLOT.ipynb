# %% [markdown]
# ## SEABORN : distplot

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
cars = sns.load_dataset('mpg').dropna()
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.set_style('darkgrid')
sns.distplot(cars.weight)
plt.show()
# Out:
# C:\Users\Ayush mishra\AppData\Local\Temp\ipykernel_16720\449840929.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.weight)

# %%
sns.distplot(cars.weight, kde = False)
plt.show()
# Out:
# C:\Users\Ayush mishra\AppData\Local\Temp\ipykernel_16720\3140465407.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.weight, kde = False)

# %%
sns.set_style('white')
sns.distplot(cars.weight, rug = True, kde = True, bins = 5) # bins= [1000,2000,3000 list can be passed according need]
plt.show()
# Out:
# C:\Users\Ayush mishra\AppData\Local\Temp\ipykernel_16720\4115307450.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.weight, rug = True, kde = True, bins = 5) # bins= [1000,2000,3000 list can be passed according need]

# %%
from scipy.stats import skewnorm

sns.distplot(cars.weight, fit=skewnorm, kde=False)
# Out:
# C:\Users\Ayush mishra\AppData\Local\Temp\ipykernel_16720\336922953.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.weight, fit=skewnorm, kde=False);

# %%
sns.distplot(cars.weight, kde=False, 
             hist_kws={'alpha': 1, 'histtype': 'stepfilled', })
# Out:
# C:\Users\Ayush mishra\AppData\Local\Temp\ipykernel_16720\3089628320.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.weight, kde=False,

# %%
sns.distplot(cars.weight, kde_kws={'lw': 1, 'bw': 1})
# Out:
# C:\Users\Ayush mishra\AppData\Local\Temp\ipykernel_16720\575137949.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.weight, kde_kws={'lw': 1, 'bw': 1});
# C:\Anaconda\Lib\site-packages\seaborn\distributions.py:2496: UserWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`.
# Setting `bw_method=1`, but please see the docs for the new parameters
# and update your code. This will become an error in seaborn v0.14.0.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)

# %%
sns.distplot(cars.weight, rug=True, rug_kws={'height': 0.15})
# Out:
# C:\Users\Ayush mishra\AppData\Local\Temp\ipykernel_16720\38586743.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.weight, rug=True, rug_kws={'height': 0.15});

# %%
sns.distplot(cars.weight, rug=True, 
             rug_kws={'height': 0.15, 'color': 'xkcd:navy'})
# Out:
# C:\Users\Ayush mishra\AppData\Local\Temp\ipykernel_16720\1055253814.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.weight, rug=True,

# %%
sns.set_style('white')

plt.figure(figsize=(8,5))
sns.distplot(cars.acceleration.sample(100, random_state=100), 
             rug=True,
             kde=False,
             hist_kws={'lw': 5, 
                       'linestyle': (0, (5, 1)),
                       'alpha': 1, 
                       'histtype':'step', 
                       'color':'xkcd:dark magenta'},
             rug_kws={'lw': 3,
                      'color':'xkcd:dark magenta'}
            )
sns.distplot(cars.acceleration.sample(100, random_state=100), 
             kde=False,
             hist_kws={'alpha': 0.1,
                       'histtype':'stepfilled', 
                       'color':'xkcd:dark magenta'},
            )

sns.despine(left=True)
plt.xlabel('')
plt.xticks([])
plt.yticks([])
plt.tight_layout()

plt.savefig('03dist_styleAcc_pink.svg')
# Out:
# C:\Users\Ayush mishra\AppData\Local\Temp\ipykernel_16720\2301730236.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.acceleration.sample(100, random_state=100),
# C:\Users\Ayush mishra\AppData\Local\Temp\ipykernel_16720\2301730236.py:15: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.acceleration.sample(100, random_state=100),

# %%
import random
random.seed(11)

data = [random.gauss(2, 0.75) for _ in range(50)]
data.extend([random.gauss(-2, 0.75) for _ in range(50)])

sns.set_style('whitegrid')

plt.figure(figsize=(8,5))
sns.distplot(data, 
             rug=True,
             hist=False, 
             color='green',
             kde_kws={'lw':4, 'shade':True, 'bw':.5},
             rug_kws={'lw':2}
            )

sns.despine()
plt.xlabel('')
plt.tight_layout()

#plt.savefig('03dist_styleRand_greenKDErug.svg');
# Out:
# C:\Users\Ayush mishra\AppData\Local\Temp\ipykernel_16720\1394951190.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data,
# C:\Anaconda\Lib\site-packages\seaborn\distributions.py:2496: UserWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`.
# Setting `bw_method=0.5`, but please see the docs for the new parameters
# and update your code. This will become an error in seaborn v0.14.0.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# C:\Anaconda\Lib\site-packages\seaborn\distributions.py:2496: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)

# %%
sns.set_style('darkgrid')

data = [random.gauss(2, 0.75) for _ in range(100)]
data.extend([random.gauss(-2, 0.75) for _ in range(50)])

plt.figure(figsize=(8,5))
sns.distplot(data, 
             hist_kws={'histtype': 'stepfilled', 
                       'alpha':0.7, 'color':'xkcd:carolina blue'},
             kde_kws={'lw':3,'color':'xkcd:navy'}
            )

sns.despine()
plt.xlabel('')
plt.figure(figsize = (2,5))
plt.tight_layout()

#plt.savefig('03dist_styleRand_carolina.svg');
# Out:
# C:\Users\Ayush mishra\AppData\Local\Temp\ipykernel_16720\2092514215.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data,
