# %%
import pandas as pd

data = {
    "Name": ["Ayush", "Rahul", "Neha", "Priya"],
    "Age": [21, 22, 20, 23],
    "Marks": [85, 72, 90, 65],
    "City": ["Delhi", "Mumbai", "Delhi", "Pune"]
}

df = pd.DataFrame(data)
df
# Out:
#     Name  Age  Marks    City
# 0  Ayush   21     85   Delhi
# 1  Rahul   22     72  Mumbai
# 2   Neha   20     90   Delhi
# 3  Priya   23     65    Pune

# %%
type(df["Name"])
# Out:
# pandas.core.series.Series

# %%
df[["Name", "Marks"]]
df.head()
# Out:
#     Name  Age  Marks    City
# 0  Ayush   21     85   Delhi
# 1  Rahul   22     72  Mumbai
# 2   Neha   20     90   Delhi
# 3  Priya   23     65    Pune

# %%
df[df["Marks"]>80]
# Out:
#     Name  Age  Marks   City
# 0  Ayush   21     85  Delhi
# 2   Neha   20     90  Delhi

# %%
df[(df["Age"] >= 21) & (df["City"] == "Delhi")]
# Out:
#     Name  Age  Marks   City
# 0  Ayush   21     85  Delhi

# %%
df.sort_values(["City", "Marks"], ascending = [True, False])
# Out:
#     Name  Age  Marks    City
# 2   Neha   20     90   Delhi
# 0  Ayush   21     85   Delhi
# 1  Rahul   22     72  Mumbai
# 3  Priya   23     65    Pune

# %%
df.rename(columns = {"Marks" : "Obtained", "City" : "Location"})
# Out:
#     Name  Age  Obtained Location
# 0  Ayush   21        85    Delhi
# 1  Rahul   22        72   Mumbai
# 2   Neha   20        90    Delhi
# 3  Priya   23        65     Pune

# %%
data2= df.rename(columns ={"marks" : "Score"}, inplace = True)
# Out:
# None

# %%
import pandas as pd

data = {
    "Name": ["Ayush", "Rahul", "Neha", "Priya"],
    "Age": [21, 22, 20, 23],
    "Marks": [85, 72, 90, 65],
    "City": ["Delhi", "Mumbai", "Delhi", "Pune"]
}

df = pd.DataFrame(data)
df
# Out:
#     Name  Age  Marks    City
# 0  Ayush   21     85   Delhi
# 1  Rahul   22     72  Mumbai
# 2   Neha   20     90   Delhi
# 3  Priya   23     65    Pune

# %%
df.loc[0]
# Out:
# Name     Ayush
# Age         21
# Marks       85
# City     Delhi
# Name: 0, dtype: object

# %%
df.loc[0:2, ["Name", "Age"]]
# Out:
#     Name  Age
# 0  Ayush   21
# 1  Rahul   22
# 2   Neha   20

# %%
df.loc[df["Marks"]>80 , ["Name", "Marks"]]
# Out:
#     Name  Marks
# 0  Ayush     85
# 2   Neha     90

# %%
df.iloc[0]
# Out:
# Name     Ayush
# Age         21
# Marks       85
# City     Delhi
# Name: 0, dtype: object
