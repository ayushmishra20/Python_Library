# %% [markdown]
# tutorial python no method

# %%
abs(10)
# Out:
# 10

# %% [markdown]
# abs() it returns the absolute value of the given ( always positive )

# %%
abs(34.43)
# Out:
# 34.43

# %%
abs(-43)
# Out:
# 43

# %%
import math

# %%
math.ceil(43.4)
# Out:
# 44

# %%
math.ceil(43.1)
# Out:
# 44

# %%
math.ceil(-34.4)
# Out:
# -34

# %%
math.floor(43.5)
# Out:
# 43

# %%
math.floor(-54.9)
# Out:
# -55

# %%
math.exp(10)
# Out:
# 22026.465794806718

# %%
math.exp(2)
# Out:
# 7.38905609893065

# %%
math.fabs(10.5)
# Out:
# 10.5

# %%
math.fabs(-10)
# Out:
# 10.0

# %%
math.log(2)
# Out:
# 0.6931471805599453

# %%
math.log10(10)
# Out:
# 1.0

# %%
max(100,20,40,101,50,40)
# Out:
# 101

# %%
min(100,90,0,99)
# Out:
# 0

# %%
import math
math.pow(2,5)
# Out:
# 32.0

# %%
math.pow(3,9)
# Out:
# 19683.0

# %%
math.sqrt(16)
# Out:
# 4.0

# %%
import math
math.sin(90)
# Out:
# 0.8939966636005579

# %%
math.tan(0)
# Out:
# 0.0
